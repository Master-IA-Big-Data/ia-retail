# %% [markdown]
# Creamos una instalación minima para trabajar con Colab

# %%
# Instalación mínima para Google Colab
# !pip install -q pandas numpy matplotlib seaborn scikit-learn joblib

# %% [markdown]
# Importamos todas las librerias y dependencias que nos pueden hacer falta en un primer momento

# %%
#importamos librerias y dependencias y las configuraciones
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import joblib
import os

#opciones para la visualizacion de las tablas
pd.set_option('display.max_columns', None)
pd.set_option("display.width", 120)
pd.set_option("display.float_format", lambda x: f"{x:,.2f}")

#configuracion de graficos
sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (10, 6)

#gestion de warning
warnings.filterwarnings('ignore')

print("Configuración del entorno\n")
print(f"Pandas: {pd.__version__}")
print(f"Numpy: {np.__version__}")
print(f"Matplotlib: {plt.matplotlib.__version__}")
print(f"Seaborn: {sns.__version__}")
# Out:
# Configuración del entorno
#
# Pandas: 2.2.2
# Numpy: 2.0.2
# Matplotlib: 3.10.0
# Seaborn: 0.13.2

# %% [markdown]
# Para trabajar con el dataset, subimos una copia del original en la carpeta compartida de DRIVE dataset/original/data.csv, descargarla en local e ir subiendo a esa carpeta compartida las distintas versiones ya editadas en dataset/limpio_versiones/ con el formato data_persona_v01.csv y un comentario en dicord de lo que se ha hecho en esa version.
#
# En el paso final de entrega, esta celda se cambiara por una carga directa desde la web de kaggle

# %%
#descargar una copia del data en local y luego cargarla en el notebook
from google.colab import files
dataset = files.upload()
# Out:
#      <input type="file" id="files-a87354b1-8136-419b-9d54-b4f0e5dd9e00" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a87354b1-8136-419b-9d54-b4f0e5dd9e00">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Una vez subido desde el local cargamos el dataset en colab, mostramos las primeras filas para hacernos una idea.

# %%
# cargamos el dataset y mostramos las primeras filas
try:
    nombre_archivo = list(dataset.keys())[0]
    df = pd.read_csv(nombre_archivo, encoding="cp1252")
    print(f"Archivo {nombre_archivo} cargado exitosamente.")
    display(df.head())
except FileNotFoundError:
    print(f"Error: No se encontró el archivo: {nombre_archivo}")
except Exception as e:
    print(f"Ocurrió un error al cargar el archivo: {e}")
# Out:
# Archivo data.csv cargado exitosamente.
#   InvoiceNo StockCode                          Description  Quantity     InvoiceDate  UnitPrice  CustomerID  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6  12/1/2010 8:26       2.55   17,850.00
# 1    536365     71053                  WHITE METAL LANTERN         6  12/1/2010 8:26       3.39   17,850.00
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8  12/1/2010 8:26       2.75   17,850.00
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6  12/1/2010 8:26       3.39   17,850.00
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6  12/1/2010 8:26       3.39   17,850.00
#
#           Country
# 0  United Kingdom
# 1  United Kingdom
# 2  United Kingdom
# 3  United Kingdom
# 4  United Kingdom

# %% [markdown]
# Vamos ha hacer una vista generar del dataset para poder analizarlo

# %%
#Vista general del dataset

#Aqui mostramos las dimensiones de dataset
print("Dimensiones del dataset:")
print(f"Filas: {df.shape[0]}")
print(f"Columnas: {df.shape[1]}")

#Todos los nombres de las columnas.
print("\nNombres de las columnas:")
print(df.columns)

#Tambien mostramos las 5 primeras y ultimas 5 filas del dataset
print("\nPrimeras 5 filas del dataset:")
display(df.head())
print("\nUltimas 5 filas del dataset:")
display(df.tail())

#En esta parte mostramos los tipos de datos y estructura del dataset
print("\nTipos de datos y estructura del dataset:")
display(df.info())

#Hacemos un resumen estadistico
print("\nResumen estadístico del dataset:")
display(df.describe())

#Hacemos un resumen descriptivo
print("\nResumen descriptivo del dataset:")
display(df.describe(include='object'))
# Out:
# Dimensiones del dataset:
# Filas: 541909
# Columnas: 8
#
# Nombres de las columnas:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate', 'UnitPrice', 'CustomerID', 'Country'], dtype='object')
#
# Primeras 5 filas del dataset:
#   InvoiceNo StockCode                          Description  Quantity     InvoiceDate  UnitPrice  CustomerID  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6  12/1/2010 8:26       2.55   17,850.00
# 1    536365     71053                  WHITE METAL LANTERN         6  12/1/2010 8:26       3.39   17,850.00
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8  12/1/2010 8:26       2.75   17,850.00
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6  12/1/2010 8:26       3.39   17,850.00
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6  12/1/2010 8:26       3.39   17,850.00
#
#           Country
# 0  United Kingdom
# 1  United Kingdom
# 2  United Kingdom
# ...

# %% [markdown]
# Después de tener una vista más generalizada del mismo, pasamos a un análisis más exaustivo.

# %%
#Identificacion de valores nulos

null = df.isnull().sum()
porcentaje_null = (null / len(df)) * 100


#Mostramos
print("Valores nulos por columna:")
print(null)
print("\nPorcentaje de valores nulos por columna:")
print(porcentaje_null)

#tabla

df_nulos = pd.DataFrame({
    "Nulos": null,
    "Porcentaje (%)": porcentaje_null.round(2)
})

df_nulos = df_nulos[df_nulos["Nulos"] > 0]
df_nulos = df_nulos.sort_values(by="Nulos", ascending=False)

if not df_nulos.empty:
    print("Columnas con valores nulos (conteo y porcentaje):")
    display(df_nulos)
else:
    print("No se encontraron valores nulos en el DataFrame.")

total_columnas_con_nulos = df_nulos.shape[0]

print(f"\nNúmero de columnas con al menos un valor nulo: {total_columnas_con_nulos}")

if total_columnas_con_nulos > 0:
    columna_mas_afectada = df_nulos.index[0]
    nulos_max = df_nulos.iloc[0]["Nulos"]
    porcentaje_max = df_nulos.iloc[0]["Porcentaje (%)"]

    print("Columna más afectada por valores nulos:")
    print(f"- {columna_mas_afectada}: {int(nulos_max):,} nulos ({porcentaje_max:.2f}%)")

# %% [markdown]
# Como podemos ver tenemos un 25% de valores nulos nada más que en una colunma, pasamos a identificar los duplicados.

# %%
#Identificar valores duplicados

duplicados = df.duplicated().sum()
porcentaje_duplicados = (duplicados / len(df)) * 100

print("\n--- Detección de filas duplicadas ---")
print(f"Número de filas duplicadas: {duplicados}")
print(f"Porcentaje de filas duplicadas: {porcentaje_duplicados:.2f}%")

if duplicados > 0:
    print("\nMostrando las primeras 10 filas involucradas en duplicados:")

    duplicados_ejemplo = (
        df[df.duplicated(keep=False)]
        .sort_values(by=df.columns.tolist())
        .head(10)
    )

    display(duplicados_ejemplo)
else:
    print("\nNo se encontraron filas duplicadas en el DataFrame.")

if duplicados > 0:
    print(
        "Se han detectado filas repetidas exactamente en todas sus columnas. "
        "\nEsto sugiere la posible existencia de registros redundantes que deberán "
        "revisarse antes de la fase de limpieza."
    )
else:
    print("\nInterpretación inicial:")
    print("No se han detectado duplicados exactos, por lo que no sería necesario tratarlos.")

# %% [markdown]
# Hacemos una copia del dataset en la variable **dfc** para poder trabajar en la limpieza y poder hacer comparaciones con el dataset original,
# así en **df** tenemos el original y en **dfc** la copia trabajada

# %%
#hacemos una copia del dataset original para trabajar con ella y hacer comparaciones mas adelante.
dfc = df.copy()

# %% [markdown]
# Celda para guardar y descargar el dataset

# %%
dfc.to_csv("data_persona_nuevas_columnas_regresion_v01.csv", index=False)

from google.colab import files
files.download("data_persona_nuevas_columnas__regresion_v01.csv")
